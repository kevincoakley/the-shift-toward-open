# %%
import os
import csv
import json
import pandas as pd
import numpy as np

# %%
ignore_labels = [
    "filter_stopwords",
    "lemmatize",
    "model",
    "permute",
    "prompt",
    "questions",
    "temperature",
    "top_p",
    "evaluation_seconds",
]

# %%
llm_results_files = {
    "AAAI": {
        2014: [
            "../../results/experiment/raw_data/AAAI/2014/AAAI_2014_1_250.json",
            "../../results/experiment/raw_data/AAAI/2014/AAAI_2014_251_447.json",
        ],
        2015: [
            "../../results/experiment/raw_data/AAAI/2015/AAAI_2015_1_250.json",
            "../../results/experiment/raw_data/AAAI/2015/AAAI_2015_251_500.json",
            "../../results/experiment/raw_data/AAAI/2015/AAAI_2015_501_651.json",
        ],
        2016: [
            "../../results/experiment/raw_data/AAAI/2016/AAAI_2016_1_250.json",
            "../../results/experiment/raw_data/AAAI/2016/AAAI_2016_251_500.json",
            "../../results/experiment/raw_data/AAAI/2016/AAAI_2016_501_676.json",
            "../../results/experiment/raw_data/AAAI/2016/AAAI_2016_errors.json",
        ],
        2017: [
            "../../results/experiment/raw_data/AAAI/2017/AAAI_2017_1_250.json",
            "../../results/experiment/raw_data/AAAI/2017/AAAI_2017_251_500.json",
            "../../results/experiment/raw_data/AAAI/2017/AAAI_2017_501_750.json",
            "../../results/experiment/raw_data/AAAI/2017/AAAI_2017_751_764.json",
        ],
        2018: [
            "../../results/experiment/raw_data/AAAI/2018/AAAI_2018_1_250.json",
            "../../results/experiment/raw_data/AAAI/2018/AAAI_2018_251_500.json",
            "../../results/experiment/raw_data/AAAI/2018/AAAI_2018_501_750.json",
            "../../results/experiment/raw_data/AAAI/2018/AAAI_2018_751_1000.json",
            "../../results/experiment/raw_data/AAAI/2018/AAAI_2018_1001_1100.json",
        ],
        2019: [
            "../../results/experiment/raw_data/AAAI/2019/AAAI_2019_1_250.json",
            "../../results/experiment/raw_data/AAAI/2019/AAAI_2019_251_500.json",
            "../../results/experiment/raw_data/AAAI/2019/AAAI_2019_501_750.json",
            "../../results/experiment/raw_data/AAAI/2019/AAAI_2019_751_1000.json",
            "../../results/experiment/raw_data/AAAI/2019/AAAI_2019_1001_1250.json",
            "../../results/experiment/raw_data/AAAI/2019/AAAI_2019_1251_1341.json",
            "../../results/experiment/raw_data/AAAI/2019/AAAI_2019_errors.json",
            "../../results/experiment/raw_data/AAAI/2019/AAAI_2019_missed.json",
        ],
        2020: [
            "../../results/experiment/raw_data/AAAI/2020/AAAI_2020_1_250.json",
            "../../results/experiment/raw_data/AAAI/2020/AAAI_2020_251_500.json",
            "../../results/experiment/raw_data/AAAI/2020/AAAI_2020_501_750.json",
            "../../results/experiment/raw_data/AAAI/2020/AAAI_2020_751_1000.json",
            "../../results/experiment/raw_data/AAAI/2020/AAAI_2020_1001_1250.json",
            "../../results/experiment/raw_data/AAAI/2020/AAAI_2020_1251_1500.json",
            "../../results/experiment/raw_data/AAAI/2020/AAAI_2020_1501_1607.json",
            "../../results/experiment/raw_data/NeurIPS/2022/NeurIPS_2022_1251_1500.json",
            "../../results/experiment/raw_data/NeurIPS/2022/NeurIPS_2022_1501_1750.json",
            "../../results/experiment/raw_data/NeurIPS/2022/NeurIPS_2022_1751_2000.json",
            "../../results/experiment/raw_data/NeurIPS/2022/NeurIPS_2022_2001_2250.json",
            "../../results/experiment/raw_data/NeurIPS/2022/NeurIPS_2022_2251_2500.json",
            "../../results/experiment/raw_data/NeurIPS/2022/NeurIPS_2022_2501_2671.json",
            "../../results/experiment/raw_data/NeurIPS/2022/NeurIPS_2022_errors.json",
        ],
        2023: [
            "../../results/experiment/raw_data/NeurIPS/2023/NeurIPS_2023_1_250.json",
            "../../results/experiment/raw_data/NeurIPS/2023/NeurIPS_2023_251_500.json",
            "../../results/experiment/raw_data/NeurIPS/2023/NeurIPS_2023_501_750.json",
            "../../results/experiment/raw_data/NeurIPS/2023/NeurIPS_2023_751_1000.json",
            "../../results/experiment/raw_data/NeurIPS/2023/NeurIPS_2023_1001_1250.json",
            "../../results/experiment/raw_data/NeurIPS/2023/NeurIPS_2023_1251_1500.json",
            "../../results/experiment/raw_data/NeurIPS/2023/NeurIPS_2023_1501_1750.json",
            "../../results/experiment/raw_data/NeurIPS/2023/NeurIPS_2023_1751_2000.json",
            "../../results/experiment/raw_data/NeurIPS/2023/NeurIPS_2023_2001_2250.json",
            "../../results/experiment/raw_data/NeurIPS/2023/NeurIPS_2023_2251_2500.json",
            "../../results/experiment/raw_data/NeurIPS/2023/NeurIPS_2023_2501_2750.json",
            "../../results/experiment/raw_data/NeurIPS/2023/NeurIPS_2023_2751_3000.json",
            "../../results/experiment/raw_data/NeurIPS/2023/NeurIPS_2023_3001_3218.json",
            "../../results/experiment/raw_data/NeurIPS/2023/NeurIPS_2023_errors.json",
        ],
        2024: [
            "../../results/experiment/raw_data/NeurIPS/2024/NeurIPS_2024_1_250.json",
            "../../results/experiment/raw_data/NeurIPS/2024/NeurIPS_2024_251_500.json",
            "../../results/experiment/raw_data/NeurIPS/2024/NeurIPS_2024_501_750.json",
            "../../results/experiment/raw_data/NeurIPS/2024/NeurIPS_2024_751_1000.json",
            "../../results/experiment/raw_data/NeurIPS/2024/NeurIPS_2024_1001_1250.json",
            "../../results/experiment/raw_data/NeurIPS/2024/NeurIPS_2024_1251_1500.json",
            "../../results/experiment/raw_data/NeurIPS/2024/NeurIPS_2024_1501_1750.json",
            "../../results/experiment/raw_data/NeurIPS/2024/NeurIPS_2024_1751_2000.json",
            "../../results/experiment/raw_data/NeurIPS/2024/NeurIPS_2024_2001_2250.json",
            "../../results/experiment/raw_data/NeurIPS/2024/NeurIPS_2024_2251_2500.json",
            "../../results/experiment/raw_data/NeurIPS/2024/NeurIPS_2024_2501_2750.json",
            "../../results/experiment/raw_data/NeurIPS/2024/NeurIPS_2024_2751_3000.json",
            "../../results/experiment/raw_data/NeurIPS/2024/NeurIPS_2024_3001_3250.json",
            "../../results/experiment/raw_data/NeurIPS/2024/NeurIPS_2024_3251_3500.json",
            "../../results/experiment/raw_data/NeurIPS/2024/NeurIPS_2024_3501_3750.json",
            "../../results/experiment/raw_data/NeurIPS/2024/NeurIPS_2024_3751_4000.json",
            "../../results/experiment/raw_data/NeurIPS/2024/NeurIPS_2024_4001_4250.json",
            "../../results/experiment/raw_data/NeurIPS/2024/NeurIPS_2024_4251_4494.json",
            "../../results/experiment/raw_data/NeurIPS/2024/NeurIPS_2024_errors.json",
        ],
    },
}

# %%
csv_file_path = "../../results/experiment/llm_results.csv"

csv_fields = [
    "conference",
    "year",
    "filename",
    "research_type",
    "result_outcome",
    "affiliation",
    "problem_description",
    "goal_objective",
    "research_method",
    "research_question",
    "hypothesis",
    "prediction",
    "contribution",
    "pseudocode",
    "open_source_code",
    "open_experiment_code",
    "train",
    "validation",
    "test",
    "results",
    "hardware_specification",
    "software_dependencies",
    "experiment_setup",
]

# Write CSV headers only if the file doesn't exist
write_headers = not os.path.exists(csv_file_path)

# %%
# Open CSV file for writing
with open(csv_file_path, mode="a", newline="", encoding="utf-8") as csv_file:
    csv_writer = csv.writer(csv_file)

    # Write headers if file is new
    if write_headers:
        csv_writer.writerow(csv_fields)

    # Loop through each conference and year to process the results files
    for conference in llm_results_files.keys():

        for year in llm_results_files[conference].keys():

            #
            # Exclude papers based on exclude list, create a list of keys to exclude
            #
            exclude_keys = []

            # Check if key (conference) exclude list exists
            if os.path.exists(f"../../paper_lists/excluded_papers/{conference}_{year}.csv"):
                #print("Exclude list found for conference:", conference, "year:", year)

                # Read the Filename column from the CSV file (filename - ".pdf" = key )
                with open(f"../../paper_lists/excluded_papers/{conference}_{year}.csv", 'r') as csv_file:
                    reader = csv.DictReader(csv_file)
                    for row in reader:
                        # Append the Filename to the exclude_keys list and remove the ".pdf" suffix
                        exclude_keys.append(row['Filename'].replace('.pdf', ''))

            # Loop through each results file for the conference and year
            for results_file in llm_results_files[conference][year]:

                # Check if the results file exists
                if not os.path.exists(results_file):
                    print(f"Results file {results_file} does not exist. Skipping.")
                    continue
                
                # Read the results JSON file
                with open(results_file, 'r') as file:
                    results = json.load(file)

                # Loop through the papers in the JSON data
                for key in results.keys():

                    # Skip papers that are in the exclude list
                    if key in exclude_keys:
                        continue

                    # Skip extra metadata keys
                    if key in ignore_labels:
                        continue

                    # Write to CSV
                    csv_writer.writerow(
                        [
                            conference,
                            year,
                            key,
                            results[key]["research_type"]["result"],
                            results[key]["result_outcome"]["result"],
                            results[key]["affiliation"]["result"],
                            results[key]["problem_description"]["result"],
                            results[key]["goal_objective"]["result"],
                            results[key]["research_method"]["result"],
                            results[key]["research_question"]["result"],
                            results[key]["hypothesis"]["result"],
                            results[key]["prediction"]["result"],
                            results[key]["contribution"]["result"],
                            results[key]["pseudocode"]["result"],
                            results[key]["open_source_code"]["result"],
                            results[key]["open_experiment_code"]["result"],
                            results[key]["train"]["result"],
                            results[key]["validation"]["result"],
                            results[key]["test"]["result"],
                            results[key]["results"]["result"],
                            results[key]["hardware_specification"]["result"],
                            results[key]["software_dependencies"]["result"],
                            results[key]["experiment_setup"]["result"],
                        ]
                    )

# %%
labels = [
    "research_type",
    "result_outcome",
    "affiliation",
    "problem_description",
    "goal_objective",
    "research_method",
    "research_question",
    "hypothesis",
    "prediction",
    "contribution",
    "pseudocode",
    "open_source_code",
    "open_experiment_code",
    "train",
    "validation",
    "test",
    "results",
    "hardware_specification",
    "software_dependencies",
    "experiment_setup",
]

# %%
for label in labels:
    # Create a CSV file path for the current label
    csv_file_path = f"../../results/experiment/paper_text/{label}_paper_text.csv"

    label_csv_fields = [
        "conference",
        "year",
        "filename",
        "result",
        "paper_text",
    ]
    
    # Write CSV headers only if the file doesn't exist
    write_headers = not os.path.exists(csv_file_path)

    # Open CSV file for writing
    with open(csv_file_path, mode="a", newline="", encoding="utf-8") as csv_file:
        csv_writer = csv.writer(csv_file)

        # Write headers if file is new
        if write_headers:
            csv_writer.writerow(label_csv_fields)

        # Loop through each conference and year to process the results files
        for conference in llm_results_files.keys():

            for year in llm_results_files[conference].keys():

                #
                # Exclude papers based on exclude list, create a list of keys to exclude
                #
                exclude_keys = []

                # Check if key (conference) exclude list exists
                if os.path.exists(f"../../excludes/{conference}_{year}.csv"):
                    #print("Exclude list found for conference:", conference, "year:", year)

                    # Read the Filename column from the CSV file (filename - ".pdf" = key )
                    with open(f"../../excludes/{conference}_{year}.csv", 'r') as csv_file:
                        reader = csv.DictReader(csv_file)
                        for row in reader:
                            # Append the Filename to the exclude_keys list and remove the ".pdf" suffix
                            exclude_keys.append(row['Filename'].replace('.pdf', ''))

                # Loop through each results file for the conference and year
                for results_file in llm_results_files[conference][year]:

                    # Check if the results file exists
                    if not os.path.exists(results_file):
                        print(f"Results file {results_file} does not exist. Skipping.")
                        continue
                    
                    # Read the results JSON file
                    with open(results_file, 'r') as file:
                        results = json.load(file)

                    # Loop through the papers in the JSON data
                    for key in results.keys():

                        # Skip papers that are in the exclude list
                        if key in exclude_keys:
                            continue

                        # Skip extra metadata keys
                        if key in ignore_labels:
                            continue

                        # Write to CSV
                        csv_writer.writerow(
                            [
                                conference,
                                year,
                                key,
                                results[key][label]["result"],
                                results[key][label]["paper_text"].replace('\n', ' ').replace('\r', ' '),
                            ]
                        )

# %%
sota_csv_file_path = "../../results/prompt_optimization/results_run_01.csv"

sota_results_file = "../../results/prompt_optimization/raw_data/run_01.json"

# Write CSV headers only if the file doesn't exist
write_headers = not os.path.exists(sota_csv_file_path)

# %%
# Open CSV file for writing
with open(sota_csv_file_path, mode="a", newline="", encoding="utf-8") as csv_file:
    csv_writer = csv.writer(csv_file)

    # Write headers if file is new
    if write_headers:
        csv_writer.writerow(csv_fields)

    # Read the results JSON file
    with open(sota_results_file, 'r') as file:
        results = json.load(file)

    # Loop through the papers in the JSON data
    for key in results.keys():

        # Skip extra metadata keys
        if key in ignore_labels:
            continue

        if int(key) <= 100:
            conference = "IJCAI"
            year = 2016
        elif int(key) <= 200:
            conference = "IJCAI"
            year = 2013
        elif int(key) <= 300:
            conference = "AAAI"
            year = 2016
        else:
            conference = "AAAI"
            year = 2014

        # Write to CSV
        csv_writer.writerow(
            [
                conference,
                year,
                key,
                results[key]["research_type"]["result"],
                results[key]["result_outcome"]["result"],
                results[key]["affiliation"]["result"],
                results[key]["problem_description"]["result"],
                results[key]["goal_objective"]["result"],
                results[key]["research_method"]["result"],
                results[key]["research_question"]["result"],
                results[key]["hypothesis"]["result"],
                results[key]["prediction"]["result"],
                results[key]["contribution"]["result"],
                results[key]["pseudocode"]["result"],
                results[key]["open_source_code"]["result"],
                results[key]["open_experiment_code"]["result"],
                results[key]["train"]["result"],
                results[key]["validation"]["result"],
                results[key]["test"]["result"],
                results[key]["results"]["result"],
                results[key]["hardware_specification"]["result"],
                results[key]["software_dependencies"]["result"],
                results[key]["experiment_setup"]["result"],
            ]
        )

# %%
for label in labels:
    # Create a CSV file path for the current label
    sota_csv_file_path = f"../../results/prompt_optimization/paper_text/run_01/{label}_paper_text.csv"

    csv_fields = [
        "conference",
        "year",
        "filename",
        "result",
        "paper_text",
    ]

    # Write CSV headers only if the file doesn't exist
    write_headers = not os.path.exists(sota_csv_file_path)

    # Open CSV file for writing
    with open(sota_csv_file_path, mode="a", newline="", encoding="utf-8") as csv_file:
        csv_writer = csv.writer(csv_file)

        # Write headers if file if the file doesn't exist
        if write_headers:
            csv_writer.writerow(csv_fields)

        # Read the results JSON file
        with open(sota_results_file, 'r') as file:
            results = json.load(file)

        # Loop through the papers in the JSON data
        for key in results.keys():

            # Skip extra metadata keys
            if key in ignore_labels:
                continue

            if int(key) <= 100:
                conference = "IJCAI"
                year = 2016
            elif int(key) <= 200:
                conference = "IJCAI"
                year = 2013
            elif int(key) <= 300:
                conference = "AAAI"
                year = 2016
            else:
                conference = "AAAI"
                year = 2014

            # Write to CSV
            csv_writer.writerow(
                [
                    conference,
                    year,
                    key,
                    results[key][label]["result"],
                    results[key][label]["paper_text"].replace('\n', ' ').replace('\r', ' '),
                ]
            )
